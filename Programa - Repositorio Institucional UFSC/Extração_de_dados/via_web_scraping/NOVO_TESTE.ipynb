# %% [markdown]
# <a href="https://colab.research.google.com/github/iahistoriaufsc2023/Repositorio_UFSC/blob/main/Programa%20-%20Repositorio%20Institucional%20UFSC/Extrac%CC%A7a%CC%83o_de_dados/via_web_scraping/NOVO_TESTE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##TESTE DE NOVA INCLUSÃO DE NOTEBOOK
